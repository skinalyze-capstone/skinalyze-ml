# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import shutil
from google.colab import drive
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import Image

# %% [markdown]
# # Import Dataset

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Pre Processing Dataset

# %%
# Path folder di Google Drive
folder_path = '/content/drive/My Drive/Capstone/Dataset'

# List semua file dalam folder
file_names = os.listdir(folder_path)
print(f"Files in folder: {file_names}")
# Out:
# Files in folder: ['Milia', 'Acne', 'Bags', 'Bopeng', 'Bruntusan', 'Redness']

# %% [markdown]
# ## Convert Milia Image to .jpg

# %%
def convert_to_jpeg(input_dir, output_dir):
    """
    Mengonversi semua gambar dalam folder input_dir ke format JPEG dan menyimpannya di output_dir.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    valid_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')  # Format gambar yang didukung
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(valid_formats):
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".jpg")

                try:
                    # Buka gambar
                    with Image.open(input_path) as img:
                        # Konversi ke mode RGB jika diperlukan
                        img = img.convert("RGB")
                        # Simpan gambar dalam format JPEG
                        img.save(output_path, "JPEG")
                        print(f"Berhasil mengonversi: {input_path} -> {output_path}")
                except Exception as e:
                    print(f"Gagal mengonversi: {input_path}. Error: {e}")

# Direktori input dan output
input_directory = "/content/drive/My Drive/Capstone/Dataset/Milia"  # Ganti dengan path folder gambar Anda
output_directory = "/content/drive/My Drive/Capstone/Dataset2/Milia"  # Ganti dengan path folder tujuan

# Jalankan konversi
convert_to_jpeg(input_directory, output_directory)
# Out:
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Milia/Milia_15.jpg -> /content/drive/My Drive/Capstone/Dataset2/Milia/Milia_15.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Milia/Milia_11.jpg -> /content/drive/My Drive/Capstone/Dataset2/Milia/Milia_11.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Milia/Milia_100.jpg -> /content/drive/My Drive/Capstone/Dataset2/Milia/Milia_100.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Milia/Milia_10.jpg -> /content/drive/My Drive/Capstone/Dataset2/Milia/Milia_10.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Milia/Milia_1.jpg -> /content/drive/My Drive/Capstone/Dataset2/Milia/Milia_1.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Milia/Milia_13.jpg -> /content/drive/My Drive/Capstone/Dataset2/Milia/Milia_13.jpg
# ...

# %% [markdown]
# ## Covert Acne Image to .jpg

# %%
def convert_to_jpeg(input_dir, output_dir):
    """
    Mengonversi semua gambar dalam folder input_dir ke format JPEG dan menyimpannya di output_dir.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    valid_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')  # Format gambar yang didukung
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(valid_formats):
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".jpg")

                try:
                    # Buka gambar
                    with Image.open(input_path) as img:
                        # Konversi ke mode RGB jika diperlukan
                        img = img.convert("RGB")
                        # Simpan gambar dalam format JPEG
                        img.save(output_path, "JPEG")
                        print(f"Berhasil mengonversi: {input_path} -> {output_path}")
                except Exception as e:
                    print(f"Gagal mengonversi: {input_path}. Error: {e}")

# Direktori input dan output
input_directory = "/content/drive/My Drive/Capstone/Dataset/Acne"  # Ganti dengan path folder gambar Anda
output_directory = "/content/drive/My Drive/Capstone/Dataset2/Acne"  # Ganti dengan path folder tujuan

# Jalankan konversi
convert_to_jpeg(input_directory, output_directory)
# Out:
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Acne/Acne_108.jpg -> /content/drive/My Drive/Capstone/Dataset2/Acne/Acne_108.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Acne/Acne_13.jpg -> /content/drive/My Drive/Capstone/Dataset2/Acne/Acne_13.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Acne/Acne_27.jpg -> /content/drive/My Drive/Capstone/Dataset2/Acne/Acne_27.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Acne/Acne_25.jpg -> /content/drive/My Drive/Capstone/Dataset2/Acne/Acne_25.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Acne/Acne_11.jpg -> /content/drive/My Drive/Capstone/Dataset2/Acne/Acne_11.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Acne/Acne_14.jpg -> /content/drive/My Drive/Capstone/Dataset2/Acne/Acne_14.jpg
# ...

# %% [markdown]
# ## Covert Bags Image to .jpg

# %%
def convert_to_jpeg(input_dir, output_dir):
    """
    Mengonversi semua gambar dalam folder input_dir ke format JPEG dan menyimpannya di output_dir.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    valid_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')  # Format gambar yang didukung
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(valid_formats):
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".jpg")

                try:
                    # Buka gambar
                    with Image.open(input_path) as img:
                        # Konversi ke mode RGB jika diperlukan
                        img = img.convert("RGB")
                        # Simpan gambar dalam format JPEG
                        img.save(output_path, "JPEG")
                        print(f"Berhasil mengonversi: {input_path} -> {output_path}")
                except Exception as e:
                    print(f"Gagal mengonversi: {input_path}. Error: {e}")

# Direktori input dan output
input_directory = "/content/drive/My Drive/Capstone/Dataset/Bags"  # Ganti dengan path folder gambar Anda
output_directory = "/content/drive/My Drive/Capstone/Dataset2/Bags"  # Ganti dengan path folder tujuan

# Jalankan konversi
convert_to_jpeg(input_directory, output_directory)
# Out:
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bags/download.jpeg -> /content/drive/My Drive/Capstone/Dataset2/Bags/download.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bags/download (1).jpeg -> /content/drive/My Drive/Capstone/Dataset2/Bags/download (1).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bags/download (2).jpeg -> /content/drive/My Drive/Capstone/Dataset2/Bags/download (2).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bags/download (3).jpeg -> /content/drive/My Drive/Capstone/Dataset2/Bags/download (3).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bags/download (4).jpeg -> /content/drive/My Drive/Capstone/Dataset2/Bags/download (4).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bags/download (5).jpeg -> /content/drive/My Drive/Capstone/Dataset2/Bags/download (5).jpg
# ...

# %% [markdown]
# ## Convert Scars Image to .jpg

# %%
def convert_to_jpeg(input_dir, output_dir):
    """
    Mengonversi semua gambar dalam folder input_dir ke format JPEG dan menyimpannya di output_dir.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    valid_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')  # Format gambar yang didukung
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(valid_formats):
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".jpg")

                try:
                    # Buka gambar
                    with Image.open(input_path) as img:
                        # Konversi ke mode RGB jika diperlukan
                        img = img.convert("RGB")
                        # Simpan gambar dalam format JPEG
                        img.save(output_path, "JPEG")
                        print(f"Berhasil mengonversi: {input_path} -> {output_path}")
                except Exception as e:
                    print(f"Gagal mengonversi: {input_path}. Error: {e}")

# Direktori input dan output
input_directory = "/content/drive/My Drive/Capstone/Dataset/Bopeng"  # Ganti dengan path folder gambar Anda
output_directory = "/content/drive/My Drive/Capstone/Dataset2/Bopeng"  # Ganti dengan path folder tujuan

# Jalankan konversi
convert_to_jpeg(input_directory, output_directory)
# Out:
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bopeng/000494.jpg -> /content/drive/My Drive/Capstone/Dataset2/Bopeng/000494.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bopeng/000012.png -> /content/drive/My Drive/Capstone/Dataset2/Bopeng/000012.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bopeng/000023.jpg -> /content/drive/My Drive/Capstone/Dataset2/Bopeng/000023.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bopeng/000040.png -> /content/drive/My Drive/Capstone/Dataset2/Bopeng/000040.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bopeng/000038.png -> /content/drive/My Drive/Capstone/Dataset2/Bopeng/000038.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bopeng/000107.jpg -> /content/drive/My Drive/Capstone/Dataset2/Bopeng/000107.jpg
# ...

# %% [markdown]
# ## Convert Blackhead Image to .jpg

# %%
def convert_to_jpeg(input_dir, output_dir):
    """
    Mengonversi semua gambar dalam folder input_dir ke format JPEG dan menyimpannya di output_dir.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    valid_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')  # Format gambar yang didukung
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(valid_formats):
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".jpg")

                try:
                    # Buka gambar
                    with Image.open(input_path) as img:
                        # Konversi ke mode RGB jika diperlukan
                        img = img.convert("RGB")
                        # Simpan gambar dalam format JPEG
                        img.save(output_path, "JPEG")
                        print(f"Berhasil mengonversi: {input_path} -> {output_path}")
                except Exception as e:
                    print(f"Gagal mengonversi: {input_path}. Error: {e}")

# Direktori input dan output
input_directory = "/content/drive/My Drive/Capstone/Dataset/Bruntusan"  # Ganti dengan path folder gambar Anda
output_directory = "/content/drive/My Drive/Capstone/Dataset2/Bruntusan"  # Ganti dengan path folder tujuan

# Jalankan konversi
convert_to_jpeg(input_directory, output_directory)
# Out:
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bruntusan/OIP (43).jpg -> /content/drive/My Drive/Capstone/Dataset2/Bruntusan/OIP (43).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bruntusan/OIP (31).jpg -> /content/drive/My Drive/Capstone/Dataset2/Bruntusan/OIP (31).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bruntusan/OIP (14).jpg -> /content/drive/My Drive/Capstone/Dataset2/Bruntusan/OIP (14).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bruntusan/Fwo_DVBaMAEEf-N.jpg -> /content/drive/My Drive/Capstone/Dataset2/Bruntusan/Fwo_DVBaMAEEf-N.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bruntusan/OIP (16).jpg -> /content/drive/My Drive/Capstone/Dataset2/Bruntusan/OIP (16).jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Bruntusan/OIP (20).jpg -> /content/drive/My Drive/Capstone/Dataset2/Bruntusan/OIP (20).jpg
# ...

# %% [markdown]
# ## Convert Redness Image to .jpg

# %%
def convert_to_jpeg(input_dir, output_dir):
    """
    Mengonversi semua gambar dalam folder input_dir ke format JPEG dan menyimpannya di output_dir.
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    valid_formats = ('.jpg', '.jpeg', '.png', '.bmp', '.gif', '.tiff')  # Format gambar yang didukung
    for root, dirs, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(valid_formats):
                input_path = os.path.join(root, file)
                output_path = os.path.join(output_dir, os.path.splitext(file)[0] + ".jpg")

                try:
                    # Buka gambar
                    with Image.open(input_path) as img:
                        # Konversi ke mode RGB jika diperlukan
                        img = img.convert("RGB")
                        # Simpan gambar dalam format JPEG
                        img.save(output_path, "JPEG")
                        print(f"Berhasil mengonversi: {input_path} -> {output_path}")
                except Exception as e:
                    print(f"Gagal mengonversi: {input_path}. Error: {e}")

# Direktori input dan output
input_directory = "/content/drive/My Drive/Capstone/Dataset/Redness"  # Ganti dengan path folder gambar Anda
output_directory = "/content/drive/My Drive/Capstone/Dataset2/Redness"  # Ganti dengan path folder tujuan

# Jalankan konversi
convert_to_jpeg(input_directory, output_directory)
# Out:
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Redness/1331007806.jpg -> /content/drive/My Drive/Capstone/Dataset2/Redness/1331007806.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Redness/download.jpeg -> /content/drive/My Drive/Capstone/Dataset2/Redness/download.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Redness/119283_kulit-kemerahan.jpg -> /content/drive/My Drive/Capstone/Dataset2/Redness/119283_kulit-kemerahan.jpg
# Berhasil mengonversi: /content/drive/My Drive/Capstone/Dataset/Redness/waspada-hidung-dagu-pipi-dan-dahi-kemerahan-tanda-idap-rosacea-halodoc.jpg -> /content/drive/My Drive/Capstone/Dataset2/Redness/waspada-hidung-dagu-pipi-dan-dahi-kemerahan-tanda-idap-rosacea-halodoc.jpg
# ...

# %% [markdown]
# ## Count total image in every folder

# %%
def count_images_in_subfolders(dataset_folder):
    # Mendapatkan daftar subfolder dalam folder dataset
    subfolders = [f.name for f in os.scandir(dataset_folder) if f.is_dir()]

    for subfolder in subfolders:
        subfolder_path = os.path.join(dataset_folder, subfolder)
        total_images = 0
        # Menghitung file gambar dalam subfolder
        for root, dirs, files in os.walk(subfolder_path):
            for file in files:
                if file.lower().endswith(('.jpg', '.jpeg', '.png', '.webp')):
                    total_images += 1
        print(f"Total gambar dalam folder '{subfolder}': {total_images}")

# Ganti dengan path folder dataset Anda
dataset_folder = "/content/drive/My Drive/Capstone/Dataset2"
count_images_in_subfolders(dataset_folder)
# Out:
# Total gambar dalam folder 'Milia': 100
# Total gambar dalam folder 'Bags': 67
# Total gambar dalam folder 'Bopeng': 100
# Total gambar dalam folder 'Bruntusan': 100
# Total gambar dalam folder 'Redness': 57
# Total gambar dalam folder 'Acne': 100

# %% [markdown]
# ## Split Dataset to Train and Validation Dataset with ratio 2 : 3

# %%
def split_dataset(source_folder, dest_train_folder, dest_test_folder, test_size=0.4):
    # Mendapatkan daftar subfolder di source_folder
    subfolders = [f.name for f in os.scandir(source_folder) if f.is_dir()]

    for subfolder in subfolders:
        subfolder_path = os.path.join(source_folder, subfolder)
        # Mendapatkan daftar file dalam subfolder
        files = [f for f in os.listdir(subfolder_path) if os.path.isfile(os.path.join(subfolder_path, f))]

        # Membagi data ke dalam train dan test
        train_files, test_files = train_test_split(files, test_size=test_size, random_state=42)

        # Membuat folder train dan test untuk subfolder jika belum ada
        train_subfolder = os.path.join(dest_train_folder, subfolder)
        test_subfolder = os.path.join(dest_test_folder, subfolder)

        os.makedirs(train_subfolder, exist_ok=True)
        os.makedirs(test_subfolder, exist_ok=True)

        # Menyalin file ke folder train
        for file in train_files:
            shutil.copy(os.path.join(subfolder_path, file), os.path.join(train_subfolder, file))

        # Menyalin file ke folder test
        for file in test_files:
            shutil.copy(os.path.join(subfolder_path, file), os.path.join(test_subfolder, file))

        print(f"Data untuk folder '{subfolder}' telah dibagi ke dalam folder 'train' dan 'test'.")

# Path ke folder dataset Anda
source_folder = dataset_folder

# Folder tujuan untuk train dan test
dest_train_folder = '/content/drive/My Drive/Capstone/Coba/Train'
dest_test_folder = '/content/drive/My Drive/Capstone/Coba/Test'

# Split dataset
split_dataset(source_folder, dest_train_folder, dest_test_folder)
# Out:
# Data untuk folder 'Milia' telah dibagi ke dalam folder 'train' dan 'test'.
# Data untuk folder 'Bags' telah dibagi ke dalam folder 'train' dan 'test'.
# Data untuk folder 'Bopeng' telah dibagi ke dalam folder 'train' dan 'test'.
# Data untuk folder 'Bruntusan' telah dibagi ke dalam folder 'train' dan 'test'.
# Data untuk folder 'Redness' telah dibagi ke dalam folder 'train' dan 'test'.
# Data untuk folder 'Acne' telah dibagi ke dalam folder 'train' dan 'test'.

# %% [markdown]
# ## Count total image in every folder after split

# %%
def count_images_in_folder(folder_path):
    total_images = 0
    # Menghitung file gambar dalam folder
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.webp')):
                total_images += 1
    return total_images

def count_images_in_train_test(train_folder, test_folder):
    # Daftar subfolder di dalam train dan test
    subfolders = [f.name for f in os.scandir(train_folder) if f.is_dir()]

    for subfolder in subfolders:
        train_subfolder_path = os.path.join(train_folder, subfolder)
        test_subfolder_path = os.path.join(test_folder, subfolder)

        # Menghitung gambar dalam folder train dan test
        train_images = count_images_in_folder(train_subfolder_path)
        test_images = count_images_in_folder(test_subfolder_path)

        print(f"Jumlah gambar di folder 'train/{subfolder}': {train_images}")
        print(f"Jumlah gambar di folder 'test/{subfolder}': {test_images}")

# Path ke folder 'train' dan 'test'
train_folder = '/content/drive/My Drive/Capstone/Coba/Train'
test_folder = '/content/drive/My Drive/Capstone/Coba/Test'

# Hitung jumlah gambar dalam train dan test
count_images_in_train_test(train_folder, test_folder)
# Out:
# Jumlah gambar di folder 'train/Milia': 97
# Jumlah gambar di folder 'test/Milia': 72
# Jumlah gambar di folder 'train/Bags': 65
# Jumlah gambar di folder 'test/Bags': 46
# Jumlah gambar di folder 'train/Bopeng': 94
# Jumlah gambar di folder 'test/Bopeng': 67
# Jumlah gambar di folder 'train/Bruntusan': 97
# Jumlah gambar di folder 'test/Bruntusan': 76
# Jumlah gambar di folder 'train/Redness': 53
# Jumlah gambar di folder 'test/Redness': 39
# Jumlah gambar di folder 'train/Acne': 95
# Jumlah gambar di folder 'test/Acne': 63

# %% [markdown]
# ## Generate Train dan Validasi Dataset

# %%
# Path ke folder Train dan Test
train_dir = '/content/drive/My Drive/Capstone/Coba/Train'
val_dir = '/content/drive/My Drive/Capstone/Coba/Test'

# Generator untuk data Train
train_generator = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(256, 256),  # Ukuran gambar yang di-resize
    batch_size=32,
    label_mode='categorical', # Multi-class classification
    color_mode="rgb",
)

# Generator untuk data Test
val_generator = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=(256, 256),  # Ukuran gambar yang di-resize
    batch_size=32,
    label_mode='categorical',  # Multi-class classification
    color_mode="rgb",
)
SHUFFLE_BUFFER_SIZE = 1000
PREFETCH_BUFFER_SIZE = tf.data.AUTOTUNE

train_dataset_final = (train_generator
                       .cache()
                       .shuffle(SHUFFLE_BUFFER_SIZE)
                       .prefetch(PREFETCH_BUFFER_SIZE)
                       )

validation_dataset_final = (val_generator
                            .cache()
                            .prefetch(PREFETCH_BUFFER_SIZE)
                            )
# Out:
# Found 501 files belonging to 6 classes.
# Found 363 files belonging to 6 classes.

# %% [markdown]
# ## Augmentasi Dataset

# %%
# Define fill mode.
FILL_MODE = 'nearest'

# Create the augmentation model.
data_augmentation = tf.keras.Sequential([
        #Specify the input shape.
        tf.keras.Input(shape=(256, 256,3)),
        # Add the augmentation layers
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.2, fill_mode=FILL_MODE),
        #tf.keras.layers.RandomTranslation(0.2, 0.2, fill_mode=FILL_MODE),
        tf.keras.layers.RandomZoom(0.2, fill_mode=FILL_MODE)
        ])

# %%
def demo_augmentation(sample_image, model, num_aug):
    '''Takes a single image array, then uses a model to generate num_aug transformations'''

    # Instantiate preview list
    image_preview = []

    # Convert input image to a PIL image instance
    sample_image_pil = tf.keras.utils.array_to_img(sample_image)

    # Append the result to the list
    image_preview.append(sample_image_pil)

    # Apply the image augmentation and append the results to the list
    for i in range(NUM_AUG):
        sample_image_aug = model(tf.expand_dims(sample_image, axis=0))
        sample_image_aug_pil = tf.keras.utils.array_to_img(tf.squeeze(sample_image_aug))
        image_preview.append(sample_image_aug_pil)

    # Instantiate a subplot
    fig, axes = plt.subplots(1, NUM_AUG + 1, figsize=(12, 12))

    # Preview the images.
    for index, ax in enumerate(axes):
        ax.imshow(image_preview[index])
        ax.set_axis_off()

        if index == 0:
            ax.set_title('original')
        else:
            ax.set_title(f'augment {index}')

# %%
NUM_AUG = 4

# Get a batch of images
sample_batch = list(train_generator.take(1))[0][0]

# Apply the transformations to the first 4 images
demo_augmentation(sample_batch[0], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[1], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[2], data_augmentation, NUM_AUG)
demo_augmentation(sample_batch[3], data_augmentation, NUM_AUG)

# Delete the variable to free up some memory
del sample_batch

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Create model layers

# %%
def create_model():
    """Create the classifier model

    Returns:
        tf.keras.model.Sequential: CNN for multi-class classification
    """
    # Define the model
    model = tf.keras.models.Sequential([
        # Define an input layer
        tf.keras.layers.InputLayer(input_shape=(256, 256, 3)),
        # Rescale images
        tf.keras.layers.Rescaling(1./255),
        # First Conv2D layer with MaxPooling
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),

        # Second Conv2D layer with MaxPooling
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),

        # Second Conv2D layer with MaxPooling
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        #tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPooling2D((2, 2)),

        # Second Conv2D layer with MaxPooling
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),

        # Second Conv2D layer with MaxPooling
        tf.keras.layers.Conv2D(256, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),

        # Second Conv2D layer with MaxPooling
        tf.keras.layers.Conv2D(512, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),

        # Flatten the output and add dense layers
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1024, activation='relu'),

        # Output layer with units equal to the number of classes (24 for this dataset)
        tf.keras.layers.Dense(6, activation='softmax')  # Softmax for multi-class classification
    ])



    return model

# %% [markdown]
# ## Prepend the data augmentation layers to the base model

# %%
# Instantiate the base model
model_without_aug = create_model()

# Prepend the data augmentation layers to the base model
model_with_aug = tf.keras.models.Sequential([
    data_augmentation,
    model_without_aug
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# ## Compile Model

# %%
# Compile the model
model_with_aug.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
                  loss = 'categorical_crossentropy',
                  metrics = ["accuracy"])

# %% [markdown]
# ## Model Summary

# %%
model_with_aug.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_9 (Sequential)            │ (None, 256, 256, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_10 (Sequential)           │ (None, 6)                   │       3,296,710 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,296,710 (12.58 MB)
#  Trainable params: 3,296,710 (12.58 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Model Evaluation

# %%
print(f'Input shape: {model_with_aug.input_shape}')
print(f'Output shape: {model_with_aug.output_shape}')
# Out:
# Input shape: (None, 256, 256, 3)
# Output shape: (None, 6)

# %%
for images, labels in train_dataset_final.take(1):
	example_batch_images = images
	example_batch_labels = labels

try:
	model_with_aug.evaluate(example_batch_images, example_batch_labels, verbose=False)
except:
	print("Your model is not compatible with the dataset you defined earlier. Check that the loss function, last layer and label_mode are compatible with one another.")
else:
	predictions = model_with_aug.predict(example_batch_images, verbose=False)
	print(f"predictions have shape: {predictions.shape}")
# Out:
# predictions have shape: (32, 6)

# %% [markdown]
# ## Callbacks

# %%
class EarlyStoppingCallback(tf.keras.callbacks.Callback):

    # Define the correct function signature for on_epoch_end method
    def on_epoch_end(self, epoch, logs=0):

        # Check if the accuracy is greater or equal to 0.98
        if logs['accuracy']>= 0.98:

            # Stop training once the above condition is met
            self.model.stop_training = True

            print("\nReached 98% accuracy so cancelling training!")

# %% [markdown]
# ## Training Model

# %%
# Train your model
history = model_with_aug.fit(train_dataset_final,
                    epochs=500,
                    validation_data=validation_dataset_final, callbacks=[EarlyStoppingCallback()])
# Out:
# Epoch 1/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 6s 263ms/step - accuracy: 0.2124 - loss: 1.7864 - val_accuracy: 0.1983 - val_loss: 1.7683
# Epoch 2/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.2028 - loss: 1.7793 - val_accuracy: 0.2094 - val_loss: 1.7574
# Epoch 3/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.2071 - loss: 1.7576 - val_accuracy: 0.2094 - val_loss: 1.7549
# Epoch 4/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.1851 - loss: 1.7654 - val_accuracy: 0.2204 - val_loss: 1.7552
# Epoch 5/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.2269 - loss: 1.7565 - val_accuracy: 0.3113 - val_loss: 1.6771
# Epoch 6/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.3340 - loss: 1.6649 - val_accuracy: 0.3058 - val_loss: 1.6031
# Epoch 7/500
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.3499 - loss: 1.5667 - val_accuracy: 0.3085 - val_loss: 1.5572
# Epoch 8/500
# ...

# %% [markdown]
# ## Plotting Accuracy and Loss

# %%
# Get training and validation accuracies
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Get number of epochs
epochs = range(len(acc))

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
fig.suptitle('Training and validation accuracy')

for i, (data, label) in enumerate(zip([(acc, val_acc), (loss, val_loss)], ["Accuracy", "Loss"])):
    ax[i].plot(epochs, data[0], 'r', label="Training " + label)
    ax[i].plot(epochs, data[1], 'b', label="Validation " + label)
    ax[i].legend()
    ax[i].set_xlabel('epochs')

plt.show()

# %% [markdown]
# ## Test Model with other image

# %%
# Create the widget and take care of the display
from ipywidgets import widgets
from io import BytesIO
import tensorflow as tf
import numpy as np

# Initialize the file upload widget
uploader = widgets.FileUpload(accept="image/*", multiple=True)
display(uploader)
out = widgets.Output()
display(out)

# Define a function to handle predictions
def file_predict(filename, file, out, threshold=0.3):
    """A function for creating the prediction and printing the output."""
    # Load and preprocess the image
    image = tf.keras.utils.load_img(file, target_size=(256, 256))
    image = tf.keras.utils.img_to_array(image)
    image = np.expand_dims(image, axis=0)

    # Replace 'model_with_aug' with your trained model
    prediction = model_with_aug.predict(image, verbose=0)[0]

    # Classes corresponding to the model output
    classes = ['Acne', 'Bags', 'Bopeng', 'Bruntusan', 'Milia', 'Redness']

    # Get the predictions that exceed the threshold
    above_threshold_indices = [i for i, prob in enumerate(prediction) if prob > threshold]

    # Display only if there are predictions above the threshold
    if above_threshold_indices:
        with out:
            print(f'\nModel output for {filename}:')
            for i in above_threshold_indices:
                print(f'  - {classes[i]} with probability {prediction[i]:.5f}')
    else:
      print("Tidak dapat mendeteksi masalah")

# Define the file upload handler
def on_upload_change(change):
    """A function for getting files from the widget and running the prediction."""
    items = change['new']  # Access the newly uploaded files
    for filename, file_info in items.items():  # Loop through each uploaded file
        file_jpgdata = BytesIO(file_info['content'])
        file_predict(filename, file_jpgdata, out)

# Attach the observer to the uploader widget
uploader.observe(on_upload_change, names='value')
# Out:
# FileUpload(value={}, accept='image/*', description='Upload', multiple=True)
# Output()

# %%
from tensorflow.keras.models import model_from_json

# Contoh model sederhana
model = model_with_aug # Inisialisasi model Anda di sini

# Simpan model ke JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# Untuk membaca kembali
with open("model.json", "r") as json_file:
    loaded_model_json = json_file.read()
loaded_model = model_from_json(loaded_model_json)

# %%
# Simpan model dalam format .keras
model_with_aug.save('model_skin_disease.keras')

# %%
# Simpan model dengan bobotnya
model_with_aug.save("model.h5")

# Load kembali jika diperlukan
from tensorflow.keras.models import load_model
loaded_model = load_model("model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-7dbc25f7690d> in <cell line: 2>()
#       1 # Simpan model dengan bobotnya
# ----> 2 model_with_aug.save("model.h5")
#       3
#       4 # Load kembali jika diperlukan
#       5 from tensorflow.keras.models import load_model
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# ...

# %%
import numpy as np
import os

# Tentukan folder tujuan
output_folder = "model_weights"
os.makedirs(output_folder, exist_ok=True)
# Ekspor bobot ke file .bin
for idx, layer in enumerate(model_with_aug.layers):
    weights = layer.get_weights()  # Dapatkan bobot layer
    if weights:  # Jika layer memiliki bobot
        with open(f"layer_{idx}_weights.bin", "wb") as f:
            for w in weights:
                np.array(w).tofile(f)
